# %%
import pandas as pd
#pandas is use for importing data set in pythan
import numpy as np
#nummpy is use  large collection of high-level mathematical functions to operate 
import matplotlib.pyplot as plt
#Matplotlib is a plotting library for creating static, animated, and interactive visualizations in Python
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
from datetime import datetime

# %%
Statewise_Test =  pd.read_csv("/content/StatewiseTestingDetails.csv")

# %%
Statewise_Test.head()
# Out:
#          Date                        State  TotalSamples Negative  Positive
# 0  2020-04-17  Andaman and Nicobar Islands        1403.0     1210      12.0
# 1  2020-04-24  Andaman and Nicobar Islands        2679.0      NaN      27.0
# 2  2020-04-27  Andaman and Nicobar Islands        2848.0      NaN      33.0
# 3  2020-05-01  Andaman and Nicobar Islands        3754.0      NaN      33.0
# 4  2020-05-16  Andaman and Nicobar Islands        6677.0      NaN      33.0

# %%
Statewise_Test['Date'] = Statewise_Test['Date'].astype('datetime64[ns]')
Statewise_Test.head()
# Out:
#         Date                        State  TotalSamples Negative  Positive
# 0 2020-04-17  Andaman and Nicobar Islands        1403.0     1210      12.0
# 1 2020-04-24  Andaman and Nicobar Islands        2679.0      NaN      27.0
# 2 2020-04-27  Andaman and Nicobar Islands        2848.0      NaN      33.0
# 3 2020-05-01  Andaman and Nicobar Islands        3754.0      NaN      33.0
# 4 2020-05-16  Andaman and Nicobar Islands        6677.0      NaN      33.0

# %%
Statewise_Test.shape
# Out:
# (16336, 5)

# %%
Statewise_Test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16336 entries, 0 to 16335
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          16336 non-null  datetime64[ns]
#  1   State         16336 non-null  object
#  2   TotalSamples  16336 non-null  float64
#  3   Negative      6969 non-null   object
#  4   Positive      5662 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 638.2+ KB

# %%
Statewise_Test.isnull().sum()  #is null is cheack and count the nan value in each columns
# Out:
# Date                0
# State               0
# TotalSamples        0
# Negative         9367
# Positive        10674
# dtype: int64

# %%
Statewise_Test['Negative'] = Statewise_Test['TotalSamples'] - Statewise_Test['Positive']
Statewise_Test = Statewise_Test.dropna()
Statewise_Test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5662 entries, 0 to 15982
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          5662 non-null   datetime64[ns]
#  1   State         5662 non-null   object
#  2   TotalSamples  5662 non-null   float64
#  3   Negative      5662 non-null   float64
#  4   Positive      5662 non-null   float64
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 265.4+ KB

# %%
covid_testing_state = Statewise_Test.groupby('State')['TotalSamples','Negative','Positive'].max().reset_index()
covid_testing_state["Positive_percentage"] = ((Statewise_Test["Positive"] / Statewise_Test["TotalSamples"]) * 100)
covid_testing_state.style.background_gradient(cmap='gist_earth_r')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# <style  type="text/css" >
# #T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row0_col1,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row0_col2,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row34_col4{
#             background-color:  #f5e7e6;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row0_col3,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row2_col1,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row2_col2,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row9_col3,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row20_col1,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row20_col2{
#             background-color:  #fcf8f8;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row0_col4{
#             background-color:  #3a8d65;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row1_col1{
#             background-color:  #caa87b;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row1_col2{
#             background-color:  #ccaa80;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row1_col3{
#             background-color:  #d5b194;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row1_col4{
#             background-color:  #1f557b;
#             color:  #f1f1f1;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row2_col3,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row5_col1,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row5_col2,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row5_col3,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row7_col1,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row7_col2,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row7_col3,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row12_col3,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row17_col1,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row17_col2,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row17_col3,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row20_col3,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row21_col1,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row21_col2,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row21_col3,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row22_col1,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row22_col2,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row22_col3,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row23_col1,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row23_col2,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row23_col3,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row26_col4,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row28_col1,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row28_col2,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row28_col3,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row31_col4{
#             background-color:  #fdfbfb;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row2_col4,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row18_col1,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row18_col2,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row19_col3{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row3_col1,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row3_col2,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row9_col4,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row10_col4,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row11_col4{
#             background-color:  #d6b196;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row3_col3,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row22_col4,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row33_col2{
#             background-color:  #eed8d4;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row3_col4{
#             background-color:  #37886e;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row4_col1,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row8_col1,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row8_col3,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row30_col2{
#             background-color:  #e3c3b6;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row4_col2,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row19_col4{
#             background-color:  #e4c5b9;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row4_col3{
#             background-color:  #edd5d1;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row4_col4{
#             background-color:  #c6a574;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row5_col4{
#             background-color:  #cdaa82;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row6_col1,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row6_col2{
#             background-color:  #f4e4e3;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row6_col3,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row9_col1,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row12_col1,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row33_col3{
#             background-color:  #fbf5f5;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row6_col4{
#             background-color:  #d0ad8a;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row7_col4,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row15_col2,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row26_col1,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row26_col2{
#             background-color:  #d1ae8c;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row8_col2,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row10_col3,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row34_col3{
#             background-color:  #e6c7bc;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row8_col4,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row27_col1{
#             background-color:  #d4b091;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row9_col2,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row12_col2,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row30_col4{
#             background-color:  #faf2f2;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row10_col1{
#             background-color:  #b2b65d;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row10_col2{
#             background-color:  #afb55c;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row11_col1{
#             background-color:  #82a954;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row11_col2{
#             background-color:  #81a854;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row11_col3,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row15_col1{
#             background-color:  #ceab85;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row12_col4{
#             background-color:  #d8b49b;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row13_col1,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row13_col2,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row24_col3{
#             background-color:  #ecd3ce;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row13_col3,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row27_col4{
#             background-color:  #f9efef;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row13_col4,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row14_col4{
#             background-color:  #d9b59d;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row14_col1{
#             background-color:  #225e7c;
#             color:  #f1f1f1;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row14_col2{
#             background-color:  #1e537b;
#             color:  #f1f1f1;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row14_col3{
#             background-color:  #c1a367;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row15_col3{
#             background-color:  #cfac87;
#             color:  #000000;
#         }#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row15_col4,#T_22c6c8c0_64d6_11ec_869e_0242ac1c0002row16_col4{
#             background-color:  #dab7a0;

# %% [markdown]
# # Top 10 states with highest number of Total Samples

# %%
px.bar(x=covid_testing_state.nlargest(10,"TotalSamples")["State"],
       y = covid_testing_state.nlargest(10,"TotalSamples")["TotalSamples"],
       labels={'y':'Total Samples','x':'State'},
       color_discrete_sequence=px.colors.sequential.haline,
       title="Top 10 states with highest number of Total Samples")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1ef5e10c-c196-4306-9e7e-587bcb7dbb49" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1ef5e10c-c196-4306-9e7e-587bcb7dbb49")) {
#                     Plotly.newPlot(
#                         '1ef5e10c-c196-4306-9e7e-587bcb7dbb49',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Total Samples=%{y}", "legendgroup": "", "marker": {"color": "rgb(41, 24, 107)"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Madhya Pradesh", "Jharkhand", "Kerala", "Maharashtra", "Haryana", "Gujarat", "Tamil Nadu", "Uttar Pradesh", "Andhra Pradesh", "Karnataka"], "xaxis": "x", "y": [13853243.0, 11066130.0, 9659492.0, 8548036.0, 5913873.0, 4356062.0, 4062943.0, 3209587.0, 2534304.0, 2314485.0], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %% [markdown]
# # Top 10 states with highest number of Negative cases

# %%
px.bar(x=covid_testing_state.nlargest(10,"Negative")["State"],
       y = covid_testing_state.nlargest(10,"Negative")["Negative"],
       labels={'y':'Total Negative cases','x':'State'},
       color_discrete_sequence=px.colors.sequential.turbid,
       title="Top 10 states with highest number of Negative cases")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6590ced3-d2a2-4c26-9f92-ae77a1fe4652" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6590ced3-d2a2-4c26-9f92-ae77a1fe4652")) {
#                     Plotly.newPlot(
#                         '6590ced3-d2a2-4c26-9f92-ae77a1fe4652',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Total Negative cases=%{y}", "legendgroup": "", "marker": {"color": "rgb(232, 245, 171)"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Madhya Pradesh", "Jharkhand", "Kerala", "Maharashtra", "Haryana", "Gujarat", "Tamil Nadu", "Uttar Pradesh", "Andhra Pradesh", "Karnataka"], "xaxis": "x", "y": [13061511.0, 10719306.0, 8726853.0, 6909075.0, 5638736.0, 4220058.0, 3695513.0, 3082865.0, 2298779.0, 2049939.0], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %% [markdown]
# # Top 10 states with highest number of Positive cases

# %%
px.bar(x=covid_testing_state.nlargest(10,"Positive")["State"],
       y = covid_testing_state.nlargest(10,"Positive")["Positive"],
       labels={'y':'Total Positive Cases','x':'State'},
       color_discrete_sequence=px.colors.sequential.solar,
       title="Top 10 states with highest number of Positive cases")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9668edf6-6fff-481e-b670-450dd995357a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9668edf6-6fff-481e-b670-450dd995357a")) {
#                     Plotly.newPlot(
#                         '9668edf6-6fff-481e-b670-450dd995357a',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Total Positive Cases=%{y}", "legendgroup": "", "marker": {"color": "rgb(51, 19, 23)"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Maharashtra", "Kerala", "Madhya Pradesh", "Tamil Nadu", "Jharkhand", "Haryana", "Karnataka", "Andhra Pradesh", "Delhi", "Gujarat"], "xaxis": "x", "y": [1638961.0, 932639.0, 791732.0, 367430.0, 346824.0, 275137.0, 264546.0, 235525.0, 151928.0, 136004.0], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %% [markdown]
# # Top 10 states with highest Positive percentage

# %%
px.bar(x=covid_testing_state.nlargest(10,"Positive_percentage")["State"],
       y = covid_testing_state.nlargest(10,"Positive_percentage")["Positive_percentage"],
       labels={'y':'Positive Percentage','x':'State'},
       color_discrete_sequence=px.colors.sequential.Aggrnyl,
       title="Top 10 states with highest Positive percentage",
       height = 420)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f73474ef-f083-4794-9e20-2f00a30b0fe7" class="plotly-graph-div" style="height:420px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f73474ef-f083-4794-9e20-2f00a30b0fe7")) {
#                     Plotly.newPlot(
#                         'f73474ef-f083-4794-9e20-2f00a30b0fe7',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Positive Percentage=%{y}", "legendgroup": "", "marker": {"color": "rgb(36, 86, 104)"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Arunachal Pradesh", "Andhra Pradesh", "Assam", "Andaman and Nicobar Islands", "Bihar", "Chandigarh", "Chhattisgarh", "Dadra and Nagar Haveli and Daman and Diu", "Delhi", "Goa"], "xaxis": "x", "y": [1.1587078651685394, 1.007838745800672, 0.8790623335109218, 0.8553100498930863, 0.4942339373970346, 0.47379755922469485, 0.465970064953403, 0.46044370029300963, 0.45435770342833537, 0.4503889722942541], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 420, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "ty ...
